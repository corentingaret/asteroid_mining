# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import seaborn as sns

# %%
df= pd.read_csv('../data/dataset.csv')
# Out:
# /home/corentin/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#          id    spkid       full_name pdes     name prefix neo pha     H  \
# 0  a0000001  2000001         1 Ceres    1    Ceres    NaN   N   N  3.40
# 1  a0000002  2000002        2 Pallas    2   Pallas    NaN   N   N  4.20
# 2  a0000003  2000003          3 Juno    3     Juno    NaN   N   N  5.33
# 3  a0000004  2000004         4 Vesta    4    Vesta    NaN   N   N  3.00
# 4  a0000005  2000005       5 Astraea    5  Astraea    NaN   N   N  6.90
#
#    diameter  ...       sigma_i      sigma_om       sigma_w      sigma_ma  \
# 0   939.400  ...  4.608900e-09  6.168800e-08  6.624800e-08  7.820700e-09
# 1   545.000  ...  3.469400e-06  6.272400e-06  9.128200e-06  8.859100e-06
# 2   246.596  ...  3.223100e-06  1.664600e-05  1.772100e-05  8.110400e-06
# 3   525.400  ...  2.170600e-07  3.880800e-07  1.789300e-07  1.206800e-06
# 4   106.699  ...  2.740800e-06  2.894900e-05  2.984200e-05  8.303800e-06
#
#        sigma_ad       sigma_n      sigma_tp     sigma_per  class      rms
# ...

# %%
columns = list(df.columns)

# %%
x = "a00001"

# %%
url = "https://www.asterank.com/api/asterank?query={%22id%22:{%22$lt%22:%22" + x + "%22}}&limit=1"

# %%
url
# Out:
# 'https://www.asterank.com/api/asterank?query={%22id%22:{%22$lt%22:%22a00001%22}}&limit=1'

# %%
response = requests.get(url)

# %%
response.status_code == 200
# Out:
# True

# %%
response.json()
# Out:
# [{'sigma_tp': 1.327e-08,
#   'diameter': 939.4,
#   'epoch_mjd': 58600.0,
#   'ad': 2.979646696468275,
#   'producer': 'Davide Farnocchia',
#   'rms': 0.36954,
#   'H_sigma': '',
#   'closeness': 2640.0802241862843,
#   'K2': '',
#   'K1': '',
#   'M1': '',
#   'two_body': '',
#   'full_name': '1 Ceres',
#   'M2': '',
#   'sigma_per': 2.3543e-08,
#   'equinox': 'J2000',
#   'DT': '',
#   'diameter_sigma': 0.2,
#   'saved': -6778017204000.001,
#   'albedo': 0.09,
#   'moid_ld': 620.6405326,
#   'pha': 'N',
#   'neo': 'N',
#   'sigma_ad': 2.7786e-11,
#   'PC': '',
#   'profit': 522924215944.27673,
#   'spkid': 2000001.0,
#   'sigma_w': 1.1463e-08,
#   'sigma_i': 1.9267e-09,
#   'per': 1683.145700575484,
#   'id': 'a0000001',
#   'A1': '',
#   'data_arc': 24437.0,
#   'A3': '',
#   'score': 132.02401120931424,
#   'per_y': 4.6082017811786,
#   'sigma_n': 2.9918e-12,
#   'epoch_cal': 20190427.0,
#   'orbit_id': 34.0,
#   'sigma_a': 2.5823e-11,
#   'sigma_om': 1.1722e-08,
#   'A2': '',
# ...

# %%
api = list(response.json()[0].keys())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-97-52a653a8813c> in <module>
# ----> 1 api = list(response.json()[0].keys())
#
# IndexError: list index out of range

# %%
manquant2 = []
for i in api:
    if i not in columns:
        manquant2.append(i)

# %%
manquant1 = []
for i in columns:
    if i not in api:
        manquant1.append(i)

# %%
manquant2
# Out:
# ['producer',
#  'H_sigma',
#  'closeness',
#  'K2',
#  'K1',
#  'M1',
#  'two_body',
#  'M2',
#  'DT',
#  'saved',
#  'PC',
#  'profit',
#  'A1',
#  'data_arc',
#  'A3',
#  'score',
#  'A2',
#  'condition_code',
#  'rot_per',
#  'prov_des',
#  'G',
#  'last_obs',
#  'price',
#  'IR',
#  'spec_T',
#  'n_obs_used',
#  'extent',
#  'spec_B',
#  'GM',
#  'UB',
#  't_jup',
#  'BV',
#  'spec',
#  'moid_jup',
#  'first_obs',
#  'n_del_obs_used',
#  'n_dop_obs_used']

# %%
len(columns)
# Out:
# 45

# %%
a = np.array([manquant])

# %%
print(a)
# Out:
# []

# %%
columns.sort()

# %%
columns
# Out:
# ['H',
#  'a',
#  'ad',
#  'albedo',
#  'class',
#  'diameter',
#  'diameter_sigma',
#  'e',
#  'epoch',
#  'epoch_cal',
#  'epoch_mjd',
#  'equinox',
#  'full_name',
#  'i',
#  'id',
#  'ma',
#  'moid',
#  'moid_ld',
#  'n',
#  'name',
#  'neo',
#  'om',
#  'orbit_id',
#  'pdes',
#  'per',
#  'per_y',
#  'pha',
#  'prefix',
#  'q',
#  'rms',
#  'sigma_a',
#  'sigma_ad',
#  'sigma_e',
#  'sigma_i',
#  'sigma_ma',
#  'sigma_n',
#  'sigma_om',
#  'sigma_per',
#  'sigma_q',
#  'sigma_tp',
#  'sigma_w',
#  'spkid',
#  'tp',
#  'tp_cal',
#  'w']

# %%
api.sort()
api
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'BV',
#  'DT',
#  'G',
#  'GM',
#  'H',
#  'H_sigma',
#  'IR',
#  'K1',
#  'K2',
#  'M1',
#  'M2',
#  'PC',
#  'UB',
#  'a',
#  'ad',
#  'albedo',
#  'class',
#  'closeness',
#  'condition_code',
#  'data_arc',
#  'diameter',
#  'diameter_sigma',
#  'e',
#  'epoch',
#  'epoch_cal',
#  'epoch_mjd',
#  'equinox',
#  'extent',
#  'first_obs',
#  'full_name',
#  'i',
#  'id',
#  'last_obs',
#  'ma',
#  'moid',
#  'moid_jup',
#  'moid_ld',
#  'n',
#  'n_del_obs_used',
#  'n_dop_obs_used',
#  'n_obs_used',
#  'name',
#  'neo',
#  'om',
#  'orbit_id',
#  'pdes',
#  'per',
#  'per_y',
#  'pha',
#  'prefix',
#  'price',
#  'producer',
#  'profit',
#  'prov_des',
#  'q',
#  'rms',
#  'rot_per',
#  'saved',
#  'score',
#  'sigma_a',
#  'sigma_ad',
#  'sigma_e',
#  'sigma_i',
#  'sigma_ma',
#  'sigma_n',
#  'sigma_om',
#  'sigma_per',
#  'sigma_q',
#  'sigma_tp',
#  'sigma_w',
#  'spec',
#  'spec_B',
#  'spec_T',
#  'spkid',
#  't_jup',
#  'tp',
#  'tp_cal',
# ...

# %%
res = []
for i in api:
    if i not in columns:
        res.append(i)

# %%
res
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'BV',
#  'DT',
#  'G',
#  'GM',
#  'H_sigma',
#  'IR',
#  'K1',
#  'K2',
#  'M1',
#  'M2',
#  'PC',
#  'UB',
#  'closeness',
#  'condition_code',
#  'data_arc',
#  'extent',
#  'first_obs',
#  'last_obs',
#  'moid_jup',
#  'n_del_obs_used',
#  'n_dop_obs_used',
#  'n_obs_used',
#  'price',
#  'producer',
#  'profit',
#  'prov_des',
#  'rot_per',
#  'saved',
#  'score',
#  'spec',
#  'spec_B',
#  'spec_T',
#  't_jup',
#  'two_body']

# %%
df
# Out:
#               id    spkid          full_name      pdes     name prefix neo  \
# 0       a0000001  2000001            1 Ceres         1    Ceres    NaN   N
# 1       a0000002  2000002           2 Pallas         2   Pallas    NaN   N
# 2       a0000003  2000003             3 Juno         3     Juno    NaN   N
# 3       a0000004  2000004            4 Vesta         4    Vesta    NaN   N
# 4       a0000005  2000005          5 Astraea         5  Astraea    NaN   N
# ...          ...      ...                ...       ...      ...    ...  ..
# 958519  bPLS6013  3246801         (6013 P-L)  6013 P-L      NaN    NaN   N
# 958520  bPLS6331  3246834         (6331 P-L)  6331 P-L      NaN    NaN   N
# 958521  bPLS6344  3013075         (6344 P-L)  6344 P-L      NaN    NaN   Y
# 958522  bT2S2060  3246457         (2060 T-2)  2060 T-2      NaN    NaN   N
# 958523  bT3S2678  3246553         (2678 T-3)  2678 T-3      NaN    NaN   N
#
# ...

# %%
a = df.loc[0, "id"]
a
# Out:
# 'a0000001'

# %%
a[0] + a[3:] == x
# Out:
# True

# %%
a

# %%
def get_value_asterank_wid(x):
    x_bis = x[0] + x[3:]
    url = "https://www.asterank.com/api/asterank?query={%22id%22:{%22$lt%22:%22" + x_bis + "%22}}&limit=1"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()[0]['price']

# %%
get_value_asterank("a000001")
# Out:
# 8123022111651.299

# %%
if

# %%
df_test = df.sample(10)

# %%
df_test['price'] = df_test['id'].apply(get_value_asterank)

# %%
df_test
# Out:
#               id    spkid            full_name        pdes name prefix neo  \
# 908212  bK17B07E  3767274           (2017 BE7)    2017 BE7  NaN    NaN   N
# 396346  a0396347  2396347   396347 (2014 DH72)      396347  NaN    NaN   N
# 486162  a0486163  2486163  486163 (2012 XB135)      486163  NaN    NaN   N
# 795340  bK14S58U  3826110          (2014 SU58)   2014 SU58  NaN    NaN   N
# 436021  a0436022  2436022   436022 (2009 HR62)      436022  NaN    NaN   N
# 683040  bK10RC4L  3576337         (2010 RL124)  2010 RL124  NaN    NaN   N
# 419325  a0419326  2419326  419326 (2009 WR119)      419326  NaN    NaN   N
# 831243  bK15FV4A  3901588         (2015 FA314)  2015 FA314  NaN    NaN   N
# 22780   a0022781  2022781     22781 (1999 GN4)       22781  NaN    NaN   N
# 661162  bK09Sc4J  3961920         (2009 SJ384)  2009 SJ384  NaN    NaN   N
#
#         pha       H  diameter  ...  sigma_om   sigma_w  sigma_ma  \
# 908212    N  18.200       NaN  ...  0.000018  0.000098  0.000082
# ...

# %%
get_value_asterank('a00001')
# Out:
# 8123022111651.299

# %%
df['price'] = df['id'].apply(get_value_asterank)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ...

# %%
df.head(10)
# Out:
#          id    spkid       full_name pdes     name prefix neo pha     H  \
# 0  a0000001  2000001         1 Ceres    1    Ceres    NaN   N   N  3.40
# 1  a0000002  2000002        2 Pallas    2   Pallas    NaN   N   N  4.20
# 2  a0000003  2000003          3 Juno    3     Juno    NaN   N   N  5.33
# 3  a0000004  2000004         4 Vesta    4    Vesta    NaN   N   N  3.00
# 4  a0000005  2000005       5 Astraea    5  Astraea    NaN   N   N  6.90
# 5  a0000006  2000006          6 Hebe    6     Hebe    NaN   N   N  5.80
# 6  a0000007  2000007          7 Iris    7     Iris    NaN   N   N  5.60
# 7  a0000008  2000008         8 Flora    8    Flora    NaN   N   N  6.50
# 8  a0000009  2000009         9 Metis    9    Metis    NaN   N   N  6.30
# 9  a0000010  2000010       10 Hygiea   10   Hygiea    NaN   N   N  5.50
#
#    diameter  ...       sigma_i      sigma_om       sigma_w      sigma_ma  \
# 0   939.400  ...  4.608900e-09  6.168800e-08  6.624800e-08  7.820700e-09
# ...

# %%
df_test
# Out:
#               id    spkid            full_name        pdes name prefix neo  \
# 908212  bK17B07E  3767274           (2017 BE7)    2017 BE7  NaN    NaN   N
# 396346  a0396347  2396347   396347 (2014 DH72)      396347  NaN    NaN   N
# 486162  a0486163  2486163  486163 (2012 XB135)      486163  NaN    NaN   N
# 795340  bK14S58U  3826110          (2014 SU58)   2014 SU58  NaN    NaN   N
# 436021  a0436022  2436022   436022 (2009 HR62)      436022  NaN    NaN   N
# 683040  bK10RC4L  3576337         (2010 RL124)  2010 RL124  NaN    NaN   N
# 419325  a0419326  2419326  419326 (2009 WR119)      419326  NaN    NaN   N
# 831243  bK15FV4A  3901588         (2015 FA314)  2015 FA314  NaN    NaN   N
# 22780   a0022781  2022781     22781 (1999 GN4)       22781  NaN    NaN   N
# 661162  bK09Sc4J  3961920         (2009 SJ384)  2009 SJ384  NaN    NaN   N
#
#         pha       H  diameter  ...  sigma_om   sigma_w  sigma_ma  \
# 908212    N  18.200       NaN  ...  0.000018  0.000098  0.000082
# ...

# %%
df_test['price'] == 

for index, row in df_test.iterrows():
    x = row['id']
    x_bis = x[0] + x[3:]
    url = "https://www.asterank.com/api/asterank?query={%22id%22:{%22$lt%22:%22" + x_bis + "%22}}&limit=1"
    response = requests.get(url)
    if response.status_code == 200:
        if response.json()[0]['name'] == row['name']:
            row['price'] = response.json()[0]['price']
        else:
            row['price'] = ''
